# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Cleaned data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                     property_name property_type  \
# 0           0   2 BHK Flat in Sector 85 Gurgaon          flat
# 1           1  3 BHK Flat in Sector 113 Gurgaon          flat
# 2           2   3 BHK Flat in Sector 76 Gurgaon          flat
# 3           3   3 BHK Flat in Sector 43 Gurgaon          flat
# 4           4   3 BHK Flat in Sector 69 Gurgaon          flat
#
#                    society      sector  price  price_per_sqft    area  \
# 0              ss the leaf   sector 85   1.07          6524.0  1640.0
# 1  la vida by tata housing  sector 113   2.78         11346.0  2450.0
# 2     whiteland  the aspen   sector 76   3.50         11917.0  2937.0
# 3     sanskriti apartments   sector 43   2.50         13513.0  1850.0
# 4             tulip violet   sector 69   1.42          8998.0  1578.0
#
#                                         areaWithType  bedRoom  ...  \
# 0             Super Built up area 1640(152.36 sq.m.)        2  ...
# ...

# %%
df['price_per_sqft']
# Out:
# 0        6524.0
# 1       11346.0
# 2       11917.0
# 3       13513.0
# 4        8998.0
#          ...
# 3663     8376.0
# 3664     7220.0
# 3665     8509.0
# 3666     8432.0
# 3667    11423.0
# Name: price_per_sqft, Length: 3668, dtype: float64

# %%
df[(df['area'] < 250 ) & (df['bedRoom'] > 1)]
# Out:
#       Unnamed: 0                              property_name property_type  \
# 1586        1640  2 Bedroom House for sale in Garhi Harsaru         house
# 2295        2387   2 Bedroom House for sale in Baldev Nagar         house
#
#           society     sector  price  price_per_sqft   area  \
# 1586  independent  sector 17   0.32         22068.0  145.0
# 2295  independent   sector 7   0.27         12000.0  225.0
#
#                           areaWithType  bedRoom  ...  super_built_up_area  \
# 1586  Built Up area: 145 (13.47 sq.m.)        2  ...                  NaN
# 2295         Plot area 225(20.9 sq.m.)        2  ...                  NaN
#
#      built_up_area carpet_area  study room servant room store room pooja room  \
# 1586         145.0         NaN           0            0          0          0
# 2295         225.0         NaN           0            0          0          0
#
#      others  furnishing_type  luxury_score
# 1586      0                0             0
# ...

# %%
df['area'] / df['bedRoom']
# Out:
# 0       820.000000
# 1       816.666667
# 2       979.000000
# 3       616.666667
# 4       526.000000
#            ...
# 3663    636.666667
# 3664    692.500000
# 3665    615.000000
# 3666    504.000000
# 3667    604.000000
# Length: 3668, dtype: float64

# %%
df[df['area'] < 500]
# Out:
#       Unnamed: 0                                      property_name  \
# 8              9                   2 BHK Flat in Sector 99A Gurgaon
# 23            24  7 Bedroom House for sale in Ashok Vihar Phase ...
# 24            26                                1 BHK Flat in Sohna
# 54            58                   2 BHK Flat in Sector 99A Gurgaon
# 65            69             5 Bedroom House for sale in New Colony
# ...          ...                                                ...
# 3537        3669                                2 BHK Flat in Sohna
# 3545        3677                                2 BHK Flat in Sohna
# 3590        3723                    1 BHK Flat in Sector 92 Gurgaon
# 3609        3742                    2 BHK Flat in Sector 84 Gurgaon
# 3630        3763                                1 BHK Flat in Sohna
#
#      property_type                          society  \
# 8             flat                conscient habitat
# ...

# %%
df=df[df['area'] > 500]
