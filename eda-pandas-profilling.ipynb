# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("output_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       4 # Load your dataset
#       5 df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
# !pip install pandas_profiling
# Out:
# Collecting pandas_profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas_profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas_profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\hp\anaconda3\lib\site-packages (from pandas_profiling) (2.3.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas_profiling) (3.10.6)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas_profiling) (2.12.4)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas_profiling) (6.0.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas_profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas_profiling)
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas_profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas_profiling) (2.3.5)
# Collecting htmlmin>=0.1.12 (from pandas_profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [27 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\hp\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "C:\Users\hp\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\hp\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "C:\Users\hp\AppData\Local\Temp\pip-build-env-7prjoc1p\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#              ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\hp\AppData\Local\Temp\pip-build-env-7prjoc1p\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#       self.run_setup()
#       ~~~~~~~~~~~~~~^^
#     File "C:\Users\hp\AppData\Local\Temp\pip-build-env-7prjoc1p\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#       super().run_setup(setup_script=setup_script)
#       ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\hp\AppData\Local\Temp\pip-build-env-7prjoc1p\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#       exec(code, locals())
#       ~~~~^^^^^^^^^^^^^^^^
#     File "<string>", line 4, in <module>
#     File "C:\Users\hp\AppData\Local\Temp\pip-install-ln31768r\htmlmin_723bfbd665d14348a8ead80fd502a367\htmlmin\__init__.py", line 28, in <module>
#       from .main import minify, Minifier
#     File "C:\Users\hp\AppData\Local\Temp\pip-install-ln31768r\htmlmin_723bfbd665d14348a8ead80fd502a367\htmlmin\main.py", line 28, in <module>
#       import cgi
#   ModuleNotFoundError: No module named 'cgi'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'htmlmin' when getting requirements to build wheel
